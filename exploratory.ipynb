# %%
import pandas as pd
import csv
# Out:
# /var/folders/18/h0cj1n5505s6pjgnx5q6tmwm0000gn/T/ipykernel_68724/4271120294.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
planets = pd.read_csv("./planetary_systems.csv", skiprows=90)
planets.dropna(inplace=True)
planets.reset_index(inplace=True)
planets.drop("index", axis=1, inplace=True)

# %%
planets.columns
# Out:
# Index(['pl_name', 'hostname', 'sy_snum', 'sy_pnum', 'discoverymethod',
#        'disc_year', 'disc_facility', 'pl_controv_flag', 'pl_orbper',
#        'pl_orbpererr1', 'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax',
#        'pl_orbsmaxerr1', 'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade',
#        'pl_radeerr1', 'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1',
#        'pl_radjerr2', 'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1',
#        'pl_bmasseerr2', 'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1',
#        'pl_bmassjerr2', 'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen',
#        'pl_orbeccenerr1', 'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol',
#        'pl_insolerr1', 'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1',
#        'pl_eqterr2', 'pl_eqtlim', 'ttv_flag', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
#        'st_raderr2', 'st_radlim', 'st_mass', 'st_masserr1', 'st_masserr2',
#        'st_masslim', 'st_met', 'st_meterr1', 'st_meterr2', 'st_metlim',
#        'st_metratio', 'st_logg', 'st_loggerr1', 'st_loggerr2', 'st_logglim',
#        'rastr', 'ra', 'decstr', 'dec', 'sy_dist', 'sy_disterr1', 'sy_disterr2',
#        'sy_vmag', 'sy_vmagerr1', 'sy_vmagerr2', 'sy_kmag', 'sy_kmagerr1',
#        'sy_kmagerr2', 'sy_gaiamag', 'sy_gaiamagerr1', 'sy_gaiamagerr2'],
#       dtype='object')

# %%
planets.iloc[:, :-24]
# Out:
#               pl_name        hostname  sy_snum  sy_pnum discoverymethod  \
# 0    EPIC 249893012 b  EPIC 249893012        1        3         Transit
# 1    EPIC 249893012 c  EPIC 249893012        1        3         Transit
# 2    EPIC 249893012 d  EPIC 249893012        1        3         Transit
# 3           GJ 1214 b         GJ 1214        1        1         Transit
# 4            GJ 367 b          GJ 367        1        3         Transit
# ..                ...             ...      ...      ...             ...
# 133          WASP-2 b          WASP-2        2        1         Transit
# 134       WASP-77 A b       WASP-77 A        2        1         Transit
# 135        Wolf 503 b        Wolf 503        1        1         Transit
# 136            XO-7 b            XO-7        1        1         Transit
# 137          pi Men c        HD 39091        1        3         Transit
#
#      disc_year                                 disc_facility  pl_controv_flag  \
# 0         2020                                            K2                0
# 1         2020                                            K2                0
# 2         2020                                            K2                0
# 3         2009                                MEarth Project                0
# 4         2021  Transiting Exoplanet Survey Satellite (TESS)                0
# ..         ...                                           ...              ...
# 133       2007                                     SuperWASP                0
# 134       2012                                     SuperWASP                0
# 135       2018                                            K2                0
# 136       2019                                            XO                0
# 137       2018  Transiting Exoplanet Survey Satellite (TESS)                0
#
#      pl_orbper  pl_orbpererr1  ...  st_tefflim  st_rad  st_raderr1  \
# 0     3.595100   3.000000e-04  ...         0.0    1.71        0.04
# 1    15.624000   1.000000e-03  ...         0.0    1.71        0.04
# 2    35.747000   5.000000e-03  ...         0.0    1.71        0.04
# 3     1.580405   2.000000e-08  ...         0.0    0.22        0.00
# 4     0.321923   2.000000e-07  ...         0.0    0.46        0.01
# ..         ...            ...  ...         ...     ...         ...
# 133   2.152175   1.200000e-05  ...         0.0    0.87        0.03
# 134   1.360029   6.200000e-07  ...         0.0    0.91        0.03
# 135   6.001270   2.100000e-05  ...         0.0    0.69        0.02
# 136   2.864142   4.300000e-06  ...         0.0    1.48        0.02
# 137   6.267910   4.300000e-04  ...         0.0    1.19        0.00
#
#      st_raderr2  st_radlim  st_mass  st_masserr1  st_masserr2  st_masslim  \
# 0         -0.04        0.0     1.05         0.05        -0.05         0.0
# 1         -0.04        0.0     1.05         0.05        -0.05         0.0
# 2         -0.04        0.0     1.05         0.05        -0.05         0.0
# 3          0.00        0.0     0.18         0.00         0.00         0.0
# 4         -0.01        0.0     0.46         0.01        -0.01         0.0
# ..          ...        ...      ...          ...          ...         ...
# 133       -0.03        0.0     0.90         0.08        -0.07         0.0
# 134       -0.02        0.0     0.90         0.07        -0.06         0.0
# 135       -0.02        0.0     0.69         0.02        -0.02         0.0
# 136       -0.02        0.0     1.41         0.06        -0.06         0.0
# 137        0.00        0.0     1.10         0.14        -0.14         0.0
#
#      st_met
# 0     0.200
# 1     0.200
# 2     0.200
# 3     0.240
# 4    -0.010
# ..      ...
# 133   0.120
# 134  -0.100
# 135  -0.470
# 136   0.432
# 137   0.080
#
# [138 rows x 60 columns]
